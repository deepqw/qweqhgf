# %%
import pandas as pd
import numpy as np

import zipfile as zf

# %%
file = zf.ZipFile('/content/drive/MyDrive/всерос_по_ии_24/тренировочный_этап/ [R] Квартирография/train.zip')
file.extractall()

# %%
file = zf.ZipFile('/content/drive/MyDrive/всерос_по_ии_24/тренировочный_этап/ [R] Квартирография/test.zip')
file.extractall()

# %%
df_train = pd.read_csv('/content/train.csv')
df_train
# Out:
#       region_name_cat  district_cat  corpus_cat  developer_cat agreement_date  \
# 0               Город            58        1331             91     2012-04-13
# 1               Город            75        1677             91     2013-09-16
# 2            Пригород            48         316             10     2014-07-31
# 3            Пригород            48        1409             91     2012-12-30
# 4            Пригород            48        1590             91     2014-06-20
# ...               ...           ...         ...            ...            ...
# 93450           Город            49         811             66     2014-02-28
# 93451           Город            34         183             67     2012-06-01
# 93452           Город            75        1691             91     2013-07-20
# 93453           Город             1        2198            134     2014-01-09
# 93454           Город            41        2250             97     2012-05-27
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93455 entries, 0 to 93454
# Data columns (total 83 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   region_name_cat                                          93455 non-null  object
#  1   district_cat                                             93455 non-null  int64
#  2   corpus_cat                                               93455 non-null  int64
#  3   developer_cat                                            93455 non-null  int64
#  4   agreement_date                                           93455 non-null  object
#  5   floor                                                    93455 non-null  float64
#  6   square                                                   93455 non-null  float64
#  7   rooms_4                                                  93455 non-null  object
# ...

# %%
df_test = pd.read_csv('/content/test.csv')
df_test
# Out:
#       region_name_cat  district_cat  corpus_cat  developer_cat agreement_date  \
# 0            Пригород            48        1894             91     2014-11-30
# 1               Город            41        1789             97     2014-09-26
# 2            Пригород            48        1164             91     2014-11-12
# 3               Город            78         682             65     2014-08-29
# 4            Пригород            48        1651             20     2014-11-21
# ...               ...           ...         ...            ...            ...
# 31487           Город            40        1181             30     2014-08-31
# 31488           Город            78         682             65     2014-12-02
# 31489           Город            52         903             43     2014-09-10
# 31490           Город            52        1930             43     2014-12-12
# 31491        Пригород            48        2316             41     2014-09-21
#
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31492 entries, 0 to 31491
# Data columns (total 82 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   region_name_cat                                          31492 non-null  object
#  1   district_cat                                             31492 non-null  int64
#  2   corpus_cat                                               31492 non-null  int64
#  3   developer_cat                                            31492 non-null  int64
#  4   agreement_date                                           31492 non-null  object
#  5   floor                                                    31492 non-null  float64
#  6   square                                                   31492 non-null  float64
#  7   rooms_4                                                  31492 non-null  object
# ...
